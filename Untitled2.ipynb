# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %%
# zwraca losowe współrzędne x1, x2 oraz 1 dla punktów 
# w kole o środku (0.5,0.5) i promeniu 0.4, a 0 poza nim

def romb():
    x1=random.random()
    x2=random.random()
    if (x2>0.3) and (x2<0.7) and (x2>x1-0.27) and (x2<x1+0.27): # w kole
        return np.array([x1,x2,1])
    else:                                              # poza kołem
        return np.array([x1,x2,0])

# %%
probka_k=np.array([romb() for i in range(6000)])
print(probka_k.shape)
# Out:
# (6000, 3)

# %%
def draw_result(X,y): 
  fig=plt.figure(figsize=(5,5))

  # dorysowanie okręgu
  #ax=fig.add_subplot(1,1,1)
  #circ=plt.Circle((0.5,0.5), radius=.4, color='black', fill=False)
  #ax.add_patch(circ)

  plt.title("Działanie na próbce testowej",fontsize=16) 
  plt.xlim(min(X[:,0]),max(X[:,0]))
  plt.ylim(min(X[:,1]),max(X[:,1]))
  plt.scatter(X[:,0],X[:,1],c=y,
            s=5,cmap=mpl.cm.cool,norm=mpl.colors.Normalize(vmin=min(y), vmax=max(y)))

  plt.xlabel('$x_1$',fontsize=18)
  plt.ylabel('$x_2$',fontsize=18);

# %%
X, y = probka_k[:,:2], probka_k[:,2]

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5, random_state=42)

print("Shapes of datasets X_train, X_test, y_train, y_test: ",X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#narysuj dane testowe
draw_result(X_test, y_test)
# Out:
# Shapes of datasets X_train, X_test, y_train, y_test:  (3000, 2) (3000, 2) (3000,) (3000,)

# %% [markdown]
# #Trening

# %%
clf = MLPClassifier(hidden_layer_sizes=(5,5), activation='tanh', alpha=0.1, 
                    learning_rate_init=0.01, early_stopping=True,validation_fraction=0.2,verbose=True,n_iter_no_change=100,max_iter=1000)
                    #max_iter=1000) 


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# Iteration 1, loss = 0.53969244
# Validation score: 0.781667
# Iteration 2, loss = 0.52460325
# Validation score: 0.781667
# Iteration 3, loss = 0.51492026
# Validation score: 0.781667
# Iteration 4, loss = 0.50222927
# Validation score: 0.781667
# Iteration 5, loss = 0.48201331
# Validation score: 0.781667
# Iteration 6, loss = 0.45739926
# Validation score: 0.781667
# Iteration 7, loss = 0.42305105
# Validation score: 0.781667
# Iteration 8, loss = 0.37450497
# Validation score: 0.830000
# Iteration 9, loss = 0.32546450
# Validation score: 0.863333
# Iteration 10, loss = 0.28669196
# Validation score: 0.883333
# Iteration 11, loss = 0.25795273
# Validation score: 0.901667
# Iteration 12, loss = 0.22669074
# Validation score: 0.910000
# Iteration 13, loss = 0.20093339
# Validation score: 0.940000
# Iteration 14, loss = 0.17691378
# Validation score: 0.955000
# Iteration 15, loss = 0.15954982
# Validation score: 0.953333
# Iteration 16, loss = 0.14844641
# Validation score: 0.953333
# Iteration 17, loss = 0.13749718
# Validation score: 0.963333
# Iteration 18, loss = 0.13002736
# Validation score: 0.963333
# Iteration 19, loss = 0.12315212
# Validation score: 0.958333
# Iteration 20, loss = 0.11836883
# Validation score: 0.966667
# Iteration 21, loss = 0.11392461
# Validation score: 0.966667
# Iteration 22, loss = 0.10998630
# Validation score: 0.958333
# Iteration 23, loss = 0.10727740
# Validation score: 0.968333
# Iteration 24, loss = 0.10363915
# Validation score: 0.970000
# Iteration 25, loss = 0.10144617
# Validation score: 0.968333
# Iteration 26, loss = 0.09930995
# Validation score: 0.970000
# Iteration 27, loss = 0.09623450
# Validation score: 0.971667
# Iteration 28, loss = 0.09485338
# Validation score: 0.968333
# Iteration 29, loss = 0.09282750
# Validation score: 0.971667
# Iteration 30, loss = 0.08933836
# Validation score: 0.970000
# Iteration 31, loss = 0.08925233
# Validation score: 0.970000
# Iteration 32, loss = 0.08601227
# Validation score: 0.973333
# Iteration 33, loss = 0.08312955
# Validation score: 0.975000
# Iteration 34, loss = 0.08195425
# Validation score: 0.975000
# Iteration 35, loss = 0.08123629
# Validation score: 0.978333
# Iteration 36, loss = 0.07885245
# Validation score: 0.978333
# Iteration 37, loss = 0.07791227
# Validation score: 0.978333
# Iteration 38, loss = 0.07563627
# Validation score: 0.978333
# Iteration 39, loss = 0.07471788
# Validation score: 0.981667
# Iteration 40, loss = 0.07408365
# Validation score: 0.980000
# Iteration 41, loss = 0.07293277
# Validation score: 0.980000
# Iteration 42, loss = 0.07327096
# Validation score: 0.983333
# Iteration 43, loss = 0.07119993
# Validation score: 0.976667
# Iteration 44, loss = 0.07010176
# Validation score: 0.978333
# Iteration 45, loss = 0.07039876
# Validation score: 0.981667
# Iteration 46, loss = 0.07121533
# Validation score: 0.985000
# Iteration 47, loss = 0.06894570
# Validation score: 0.980000
# Iteration 48, loss = 0.07019767
# Validation score: 0.983333
# Iteration 49, loss = 0.06771057
# Validation score: 0.981667
# Iteration 50, loss = 0.06696774
# Validation score: 0.986667
# Iteration 51, loss = 0.06623152
# Validation score: 0.983333
# Iteration 52, loss = 0.06540345
# Validation score: 0.980000
# Iteration 53, loss = 0.06572922
# Validation score: 0.986667
# Iteration 54, loss = 0.06480133
# Validation score: 0.988333
# Iteration 55, loss = 0.06449363
# Validation score: 0.980000
# Iteration 56, loss = 0.06465571
# Validation score: 0.986667
# Iteration 57, loss = 0.06421883
# Validation score: 0.986667
# Iteration 58, loss = 0.06297103
# Validation score: 0.986667
# Iteration 59, loss = 0.06429804
# Validation score: 0.991667
# Iteration 60, loss = 0.06420981
# Validation score: 0.988333
# Iteration 61, loss = 0.06497845
# Validation score: 0.980000
# Iteration 62, loss = 0.06294111
# Validation score: 0.990000
# Iteration 63, loss = 0.06243535
# Validation score: 0.986667
# Iteration 64, loss = 0.06224231
# Validation score: 0.978333
# Iteration 65, loss = 0.06467914
# Validation score: 0.990000
# Iteration 66, loss = 0.06113672
# Validation score: 0.990000
# Iteration 67, loss = 0.06147516
# Validation score: 0.990000
# Iteration 68, loss = 0.06337801
# Validation score: 0.976667
# Iteration 69, loss = 0.06104300
# Validation score: 0.991667
# Iteration 70, loss = 0.06175049
# Validation score: 0.990000
# Iteration 71, loss = 0.06091926
# Validation score: 0.990000
# Iteration 72, loss = 0.05967946
# Validation score: 0.981667
# Iteration 73, loss = 0.05984012
# Validation score: 0.991667
# Iteration 74, loss = 0.05951180
# Validation score: 0.991667
# Iteration 75, loss = 0.05954838
# Validation score: 0.990000
# Iteration 76, loss = 0.05998462
# Validation score: 0.990000
# Iteration 77, loss = 0.06134064
# Validation score: 0.981667
# Iteration 78, loss = 0.06049247
# Validation score: 0.986667
# Iteration 79, loss = 0.05885403
# Validation score: 0.991667
# Iteration 80, loss = 0.06138212
# Validation score: 0.990000
# Iteration 81, loss = 0.06406139
# Validation score: 0.970000
# Iteration 82, loss = 0.06602263
# Validation score: 0.981667
# Iteration 83, loss = 0.06000708
# Validation score: 0.991667
# Iteration 84, loss = 0.05890757
# Validation score: 0.988333
# Iteration 85, loss = 0.05922498
# Validation score: 0.991667
# Iteration 86, loss = 0.05950896
# Validation score: 0.976667
# Iteration 87, loss = 0.05852901
# Validation score: 0.991667
# Iteration 88, loss = 0.05868779
# Validation score: 0.991667
# Iteration 89, loss = 0.05828172
# Validation score: 0.985000
# Iteration 90, loss = 0.05858231
# Validation score: 0.991667
# Iteration 91, loss = 0.05837736
# Validation score: 0.990000
# Iteration 92, loss = 0.05950951
# Validation score: 0.978333
# Iteration 93, loss = 0.06328445
# Validation score: 0.990000
# Iteration 94, loss = 0.05923332
# Validation score: 0.981667
# Iteration 95, loss = 0.05952175
# Validation score: 0.991667
# Iteration 96, loss = 0.05727080
# Validation score: 0.981667
# Iteration 97, loss = 0.05934617
# Validation score: 0.991667
# Iteration 98, loss = 0.05771092
# Validation score: 0.991667
# Iteration 99, loss = 0.05819578
# Validation score: 0.985000
# Iteration 100, loss = 0.05920755
# Validation score: 0.990000
# Iteration 101, loss = 0.05880129
# Validation score: 0.978333
# Iteration 102, loss = 0.05905152
# Validation score: 0.986667
# Iteration 103, loss = 0.05662321
# Validation score: 0.991667
# Iteration 104, loss = 0.05675037
# Validation score: 0.990000
# Iteration 105, loss = 0.05753173
# Validation score: 0.983333
# Iteration 106, loss = 0.05844037
# Validation score: 0.991667
# Iteration 107, loss = 0.05916615
# Validation score: 0.985000
# Iteration 108, loss = 0.06000799
# Validation score: 0.986667
# Iteration 109, loss = 0.05789201
# Validation score: 0.988333
# Iteration 110, loss = 0.05687468
# Validation score: 0.988333
# Iteration 111, loss = 0.05663763
# Validation score: 0.991667
# Iteration 112, loss = 0.05678432
# Validation score: 0.993333
# Iteration 113, loss = 0.05718090
# Validation score: 0.988333
# Iteration 114, loss = 0.05625543
# Validation score: 0.991667
# Iteration 115, loss = 0.05650655
# Validation score: 0.990000
# Iteration 116, loss = 0.05651487
# Validation score: 0.991667
# Iteration 117, loss = 0.05835687
# Validation score: 0.990000
# Iteration 118, loss = 0.05619279
# Validation score: 0.993333
# Validation score: 0.988333
# Iteration 170, loss = 0.05529135
# Validation score: 0.990000
# Iteration 171, loss = 0.05468361
# Validation score: 0.991667
# Iteration 172, loss = 0.05451376
# Validation score: 0.991667
# Iteration 173, loss = 0.05456486
# Validation score: 0.991667
# Iteration 174, loss = 0.05415999
# Validation score: 0.991667
# Iteration 175, loss = 0.05400222
# Validation score: 0.986667
# Iteration 176, loss = 0.05578092
# Validation score: 0.991667
# Iteration 177, loss = 0.05531617
# Validation score: 0.991667
# Iteration 178, loss = 0.05614128
# Validation score: 0.990000
# Iteration 179, loss = 0.05743647
# Validation score: 0.983333
# Iteration 180, loss = 0.05483306
# Validation score: 0.995000
# Iteration 181, loss = 0.05440912
# Validation score: 0.991667
# Iteration 182, loss = 0.05605179
# Validation score: 0.990000
# Iteration 183, loss = 0.05600131
# Validation score: 0.981667
# Iteration 184, loss = 0.05870772
# Validation score: 0.981667
# Iteration 185, loss = 0.05653255
# Validation score: 0.991667
# Iteration 186, loss = 0.05449509
# Validation score: 0.993333
# Iteration 187, loss = 0.05430252
# Validation score: 0.991667
# Iteration 188, loss = 0.05420358
# Validation score: 0.991667
# Iteration 189, loss = 0.05363218
# Validation score: 0.991667
# Iteration 190, loss = 0.05408126
# Validation score: 0.980000
# Iteration 191, loss = 0.05542947
# Validation score: 0.990000
# Iteration 192, loss = 0.05465117
# Validation score: 0.991667
# Iteration 193, loss = 0.05509537
# Validation score: 0.985000
# Iteration 194, loss = 0.05650129
# Validation score: 0.993333
# Iteration 195, loss = 0.05479062
# Validation score: 0.991667
# Iteration 196, loss = 0.05401305
# Validation score: 0.985000
# Iteration 197, loss = 0.05536659
# Validation score: 0.990000
# Iteration 198, loss = 0.05561172
# Validation score: 0.991667
# Iteration 199, loss = 0.05409125
# Validation score: 0.991667
# Iteration 200, loss = 0.05390026
# Validation score: 0.990000
# Iteration 201, loss = 0.05385266
# Validation score: 0.990000
# Iteration 202, loss = 0.05403138
# Validation score: 0.993333
# Iteration 203, loss = 0.05521774
# Validation score: 0.980000
# Iteration 204, loss = 0.05386196
# Validation score: 0.990000
# Iteration 205, loss = 0.05444983
# Validation score: 0.991667
# Iteration 206, loss = 0.05435001
# Validation score: 0.993333
# Iteration 207, loss = 0.05443037
# Validation score: 0.991667
# Iteration 208, loss = 0.05381892
# Validation score: 0.990000
# Iteration 209, loss = 0.05387486
# Validation score: 0.988333
# Iteration 210, loss = 0.05339493
# Validation score: 0.991667
# Iteration 211, loss = 0.05495694
# Validation score: 0.990000
# Iteration 212, loss = 0.05617720
# Validation score: 0.985000
# Iteration 213, loss = 0.05554162
# Validation score: 0.988333
# Iteration 214, loss = 0.05478952
# Validation score: 0.991667
# Iteration 215, loss = 0.05394458
# Validation score: 0.995000
# Iteration 216, loss = 0.05377128
# Validation score: 0.991667
# Iteration 217, loss = 0.05499581
# Validation score: 0.991667
# Iteration 218, loss = 0.05456218
# Validation score: 0.991667
# Iteration 219, loss = 0.05420821
# Validation score: 0.986667
# Iteration 220, loss = 0.05394984
# Validation score: 0.988333
# Iteration 221, loss = 0.05306854
# Validation score: 0.985000
# Iteration 222, loss = 0.05443088
# Validation score: 0.993333
# Iteration 223, loss = 0.05323379
# Validation score: 0.986667
# Iteration 224, loss = 0.05381568
# Validation score: 0.990000
# Iteration 225, loss = 0.05340108
# Validation score: 0.990000
# Iteration 226, loss = 0.05334334
# Validation score: 0.991667
# Iteration 227, loss = 0.05335006
# Validation score: 0.991667
# Iteration 228, loss = 0.05355722
# Validation score: 0.991667
# Iteration 229, loss = 0.05392839
# Validation score: 0.991667
# Iteration 230, loss = 0.05455216
# Validation score: 0.993333
# Iteration 231, loss = 0.05416316
# Validation score: 0.991667
# Iteration 232, loss = 0.05476251
# Validation score: 0.993333
# Iteration 233, loss = 0.05474031
# Validation score: 0.985000
# Iteration 234, loss = 0.05537625
# Validation score: 0.990000
# Iteration 235, loss = 0.05380004
# Validation score: 0.991667
# Iteration 236, loss = 0.05309442
# Validation score: 0.993333
# Iteration 237, loss = 0.05340161
# Validation score: 0.991667
# Iteration 238, loss = 0.05416872
# Validation score: 0.990000
# Iteration 239, loss = 0.05476266
# Validation score: 0.986667
# Iteration 240, loss = 0.05375542
# Validation score: 0.991667
# Iteration 241, loss = 0.05303476
# Validation score: 0.983333
# Iteration 242, loss = 0.05560002
# Validation score: 0.991667
# Iteration 243, loss = 0.05740193
# Validation score: 0.981667
# Iteration 244, loss = 0.05515382
# Validation score: 0.993333
# Iteration 245, loss = 0.05413835
# Validation score: 0.986667
# Iteration 246, loss = 0.05294071
# Validation score: 0.990000
# Iteration 247, loss = 0.05371429
# Validation score: 0.990000
# Iteration 248, loss = 0.05337290
# Validation score: 0.986667
# Iteration 249, loss = 0.05713826
# Validation score: 0.988333
# Iteration 250, loss = 0.05513462
# Validation score: 0.978333
# Iteration 251, loss = 0.05489233
# Validation score: 0.993333
# Iteration 252, loss = 0.05384268
# Validation score: 0.990000
# Iteration 253, loss = 0.05337885
# Validation score: 0.991667
# Iteration 254, loss = 0.05304662
# Validation score: 0.991667
# Iteration 255, loss = 0.05298087
# Validation score: 0.993333
# Iteration 256, loss = 0.05458341
# Validation score: 0.990000
# Iteration 257, loss = 0.05421736
# Validation score: 0.990000
# Iteration 258, loss = 0.05362887
# Validation score: 0.991667
# Iteration 259, loss = 0.05431680
# Validation score: 0.985000
# Iteration 260, loss = 0.05394580
# Validation score: 0.991667
# Iteration 261, loss = 0.05648315
# Validation score: 0.986667
# Iteration 262, loss = 0.05298703
# Validation score: 0.991667
# Iteration 263, loss = 0.05299971
# Validation score: 0.990000
# Iteration 264, loss = 0.05349767
# Validation score: 0.993333
# Iteration 265, loss = 0.05337441
# Validation score: 0.991667
# Iteration 266, loss = 0.05336078
# Validation score: 0.993333
# Iteration 267, loss = 0.05438989
# Validation score: 0.991667
# Iteration 268, loss = 0.05422964
# Validation score: 0.986667
# Iteration 269, loss = 0.05381902
# Validation score: 0.988333
# Iteration 270, loss = 0.05478154
# Validation score: 0.990000
# Iteration 271, loss = 0.05462491
# Validation score: 0.991667
# Iteration 272, loss = 0.05368314
# Validation score: 0.991667
# Iteration 273, loss = 0.05423184
# Validation score: 0.990000
# Iteration 274, loss = 0.05290219
# Validation score: 0.990000
# Iteration 275, loss = 0.05363710
# Validation score: 0.991667
# Iteration 276, loss = 0.05323000
# Validation score: 0.990000
# Iteration 277, loss = 0.05312280
# Validation score: 0.991667
# Iteration 278, loss = 0.05335831
# Validation score: 0.993333
# Iteration 279, loss = 0.05387526
# Validation score: 0.980000
# Iteration 280, loss = 0.05620880
# Validation score: 0.990000
# Iteration 281, loss = 0.05446970
# Validation score: 0.995000
# Validation score did not improve more than tol=0.000100 for 100 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(5, 5), learning_rate='constant',
#               learning_rate_init=0.01, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=100, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=True,
#               warm_start=False)
# Score =  0.9896666666666667
# [2.74674815e-06 8.71385702e-08 6.87179240e-06 ... 6.65941113e-04
#  3.49376864e-01 9.99622353e-01]

# %%
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.7816666666666666, 0.7816666666666666, 0.7816666666666666, 0.7816666666666666, 0.7816666666666666, 0.7816666666666666, 0.7816666666666666, 0.83, 0.8633333333333333, 0.8833333333333333, 0.9016666666666666, 0.91, 0.94, 0.955, 0.9533333333333334, 0.9533333333333334, 0.9633333333333334, 0.9633333333333334, 0.9583333333333334, 0.9666666666666667, 0.9666666666666667, 0.9583333333333334, 0.9683333333333334, 0.97, 0.9683333333333334, 0.97, 0.9716666666666667, 0.9683333333333334, 0.9716666666666667, 0.97, 0.97, 0.9733333333333334, 0.975, 0.975, 0.9783333333333334, 0.9783333333333334, 0.9783333333333334, 0.9783333333333334, 0.9816666666666667, 0.98, 0.98, 0.9833333333333333, 0.9766666666666667, 0.9783333333333334, 0.9816666666666667, 0.985, 0.98, 0.9833333333333333, 0.9816666666666667, 0.9866666666666667, 0.9833333333333333, 0.98, 0.9866666666666667, 0.9883333333333333, 0.98, 0.9866666666666667, 0.9866666666666667, 0.9866666666666667, 0.9916666666666667, 0.9883333333333333, 0.98, 0.99, 0.9866666666666667, 0.9783333333333334, 0.99, 0.99, 0.99, 0.9766666666666667, 0.9916666666666667, 0.99, 0.99, 0.9816666666666667, 0.9916666666666667, 0.9916666666666667, 0.99, 0.99, 0.9816666666666667, 0.9866666666666667, 0.9916666666666667, 0.99, 0.97, 0.9816666666666667, 0.9916666666666667, 0.9883333333333333, 0.9916666666666667, 0.9
fig=plt.figure(figsize=(7,7))

roc_disp = plot_roc_curve(clf, X_test, y_test)
plt.show()

#Print AUC
fpr, tpr, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)
print("Area Under Curve AUC = ",roc_auc)

#simpler method
print("Area Under Curve AUC = ",roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Area Under Curve AUC =  0.9995465939367186
# Area Under Curve AUC =  0.9995465939367186

# %%
! wget https://raw.githubusercontent.com/jzliu-100/visualize-neural-network/master/VisualizeNN.py

import VisualizeNN as VisNN
'''
print(clf.hidden_layer_sizes[0])
print(clf.n_outputs_)
print(clf.coefs_[0].shape)
print(clf.coefs_[1].shape)
print(clf.coefs_[2].shape)
'''

NN = list(clf.hidden_layer_sizes)
NN.append(clf.n_outputs_)
NN.insert(0,clf.coefs_[0].shape[0])
network=VisNN.DrawNN(NN,clf.coefs_)
network.draw()
# Out:
# --2020-12-04 15:51:03--  https://raw.githubusercontent.com/jzliu-100/visualize-neural-network/master/VisualizeNN.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9495 (9.3K) [text/plain]
# Saving to: ‘VisualizeNN.py’
#
# VisualizeNN.py      100%[===================>]   9.27K  --.-KB/s    in 0s
#
# 2020-12-04 15:51:03 (95.7 MB/s) - ‘VisualizeNN.py’ saved [9495/9495]

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

#Drzewo decyzyjne
#clf = DecisionTreeClassifier(max_depth=5)

# Wzmocnione drzewo decyzyjne BDT
clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200)


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                          class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=1,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort='deprecated',
#                                                          random_state=None,
#                                                          splitter='best'),
#                    learning_rate=1.0, n_estimators=200, random_state=None)
# Score =  0.9183333333333333
# [0.4276084  0.41917095 0.50145825 ... 0.48243364 0.48931976 0.49927664]

# %%
draw_result(X_test,Z)

# %%
from sklearn.metrics import plot_roc_curve, auc, roc_curve, roc_auc_score

fig=plt.figure(figsize=(7,7))

roc_disp = plot_roc_curve(clf, X_test, y_test)
plt.show()

#Print AUC
fpr, tpr, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)
print("Area Under Curve AUC = ",roc_auc)

#simpler method
print("Area Under Curve AUC = ",roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Area Under Curve AUC =  0.9750052813293184
# Area Under Curve AUC =  0.9750052813293184
